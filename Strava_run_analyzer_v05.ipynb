# %%
# install stravalib
# !pip install stravalib
# Out:
# Collecting stravalib
#   Downloading https://files.pythonhosted.org/packages/fe/37/9161484786583fe6a038747e9f14555830de4581f025f086697466023ec6/stravalib-0.10.2.tar.gz (88kB)
#      |████████████████████████████████| 92kB 2.3MB/s
# Collecting arrow
#   Downloading https://files.pythonhosted.org/packages/92/fa/f84896dede5decf284e6922134bf03fd26c90870bbf8015f4e8ee2a07bcc/arrow-0.15.5-py2.py3-none-any.whl (46kB)
#      |████████████████████████████████| 51kB 5.4MB/s
# Requirement already satisfied: requests<3.0dev,>=2.0 in /usr/local/lib/python3.6/dist-packages (from stravalib) (2.21.0)
# Collecting units
#   Downloading https://files.pythonhosted.org/packages/33/8c/76112215f71aad89ffecae90dd1e0a681ad8f750df994d4ce1275bca50a2/units-0.07.tar.gz
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from stravalib) (2018.9)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from stravalib) (1.12.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from arrow->stravalib) (2.6.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0dev,>=2.0->stravalib) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0dev,>=2.0->stravalib) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0dev,>=2.0->stravalib) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0dev,>=2.0->stravalib) (1.24.3)
# Building wheels for collected packages: stravalib, units
#   Building wheel for stravalib (setup.py) ... done
#   Created wheel for stravalib: filename=stravalib-0.10.2-cp36-none-any.whl size=85279 sha256=ea4b0b2a036bc942611531037f1eafdae2a2aa17169aeb9c2897d650341f4112
#   Stored in directory: /root/.cache/pip/wheels/69/cd/0d/c2769446bc388a177c1fe8917d2f657b26363f7d8043a6c535
#   Building wheel for units (setup.py) ... done
#   Created wheel for units: filename=units-0.7-cp36-none-any.whl size=23919 sha256=2dea826482031dc40397cc820b24f15b79cdbf588730731c4b5e76e4d12beba1
#   Stored in directory: /root/.cache/pip/wheels/fe/85/88/51b4cc421dd9dad17934779e59ad01462074f8b23d3c4ff545
# Successfully built stravalib units
# Installing collected packages: arrow, units, stravalib
# Successfully installed arrow-0.15.5 stravalib-0.10.2 units-0.7

# %%
# mount google drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# import modules and packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy as copy
import json
import time
import os
from stravalib.client import Client

# %%
# setup stravalib client authorization to get data
client = Client()
client_id = 43541  # personal client ID
authorize_url = client.authorization_url(client_id=client_id, redirect_uri='http://localhost/')
print(authorize_url)  # past url and copy redirected one; read out the code
# Out:
# https://www.strava.com/oauth/authorize?client_id=43541&redirect_uri=http%3A%2F%2Flocalhost%2F&approval_prompt=auto&response_type=code&scope=read%2Cactivity%3Aread

# %%
code = 'fa362c7ed3ae88eec2d9adbf5044671de83998cb'  # read out from redirected url
# get personal client_secret from login page
client_secret = 'd2331363dfeb23b176d6d6c2114bff933e3a3072'
access_token = client.exchange_code_for_token(client_id=client_id,
                                              client_secret=client_secret,
                                              code=code)

# %%
# now use toolbox to download, clean, reload etc data
